# %% [markdown]
# # Target Data - Unit Testing

# %%
import pandas as pd
target_columns = ['Open','High','Low','Close','Vol','MarketCap','WMA_90', 'H-L', 'H-PC', 'L-PC', 'True_Range', 'ATR_15',
         'basic_ub_Fast', 'basic_lb_Fast', 'final_ub_Fast', 'final_lb_Fast',
         'Super_Trend_Fast', 'basic_ub_Slow',  'basic_lb_Slow', 'final_ub_Slow',
         'final_lb_Slow', 'Super_Trend_Slow', 'Bull1', 'Bull2', 'Bull3', 'Bull31',
         'Crs_Bulldiff', 'Crs_Bull', 'Direction', 'Bull5', 'Bullish', 'Bear1',
         'Bear2', 'Bear3', 'Bear31', 'Crs_Beardiff', 'Crs_Bear', 'Bear5', 'Bearish',
         'Signal']
column_names = target_columns
file_path = "/Users/michaelnew/Dropbox/Aptana_Workspace/Skyze/Unit_Test/Test_Data/Strategies/SuperTrend CrossOver Screener/Target-Results-SuperTrendCrossScreener-bitcoin.csv"
target_results = pd.read_csv(
                                            file_path,
                                            header=None ,
                                            names = column_names,
                                            index_col=False,
                                            skiprows = 1
                                       )
target_results.head(20)
# Out:
#         Open    High     Low   Close     Vol MarketCap      WMA_90  H-L  \
# 0   20130428  135.30  135.98  132.10  134.21         -  1500520000  NaN
# 1   20130429  134.44  147.49  134.00  144.54         -  1491160000  NaN
# 2   20130430  144.00  146.93  134.05  139.00         -  1597780000  NaN
# 3   20130501  139.00  139.89  107.72  116.99         -  1542820000  NaN
# 4   20130502  116.38  125.60   92.28  105.21         -  1292190000  NaN
# 5   20130503  106.25  108.13   79.10   97.75         -  1180070000  NaN
# 6   20130504   98.10  115.00   92.50  112.50         -  1089890000  NaN
# 7   20130505  112.90  118.80  107.14  115.91         -  1254760000  NaN
# 8   20130506  115.98  124.66  106.64  112.30         -  1289470000  NaN
# 9   20130507  112.25  113.44   97.70  111.50         -  1248470000  NaN
# 10  20130508  109.60  115.78  109.60  113.57         -  1219450000  NaN
# 11  20130509  113.20  113.46  109.26  112.67         -  1259980000  NaN
# 12  20130510  112.80  122.00  111.55  117.20         -  1255970000  NaN
# 13  20130511  117.70  118.68  113.01  115.24         -  1311050000  NaN
# 14  20130512  115.64  117.45  113.44  115.00         -  1288630000  NaN
# 15  20130513  114.82  118.70  114.50  117.98         -  1279980000  NaN
# 16  20130514  117.98  119.80  110.25  111.50         -  1315720000  NaN
# 17  20130515  111.40  115.81  103.50  114.22         -  1242760000  NaN
# 18  20130516  114.22  118.76  112.20  118.76         -  1274620000  NaN
# 19  20130517  118.21  125.30  116.57  123.02         -  1319590000  NaN
#
#      H-PC   L-PC   ...    Bullish  Bear1  Bear2  Bear3  Bear31  Crs_Beardiff  \
# 0    3.88    NaN   ...        NaN    NaN    NaN    NaN     NaN           NaN
# 1   13.49  13.28   ...        NaN    NaN    NaN    NaN     NaN           NaN
# 2   12.88   2.39   ...        NaN    NaN    NaN    NaN     NaN           NaN
# 3   32.17   0.89   ...        NaN    NaN    NaN    NaN     NaN           NaN
# 4   33.32   8.61   ...        NaN    NaN    NaN    NaN     NaN           NaN
# 5   29.03   2.92   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 6   22.50  17.25   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 7   11.66   6.30   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 8   18.02   8.75   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 9   15.74   1.14   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 10   6.18   4.28   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 11   4.20   0.11   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 12  10.45   9.33   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 13   5.67   1.48   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 14   4.01   2.21   ...        0.0    NaN    NaN    NaN     NaN           NaN
# 15   4.20   3.70   ...        0.0    NaN    NaN  False     NaN           NaN
# 16   9.55   1.82   ...        0.0    NaN    NaN  False    True          True
# 17  12.31   4.31   ...        0.0    NaN    NaN  False    True          True
# 18   6.56   4.54   ...        0.0    NaN    NaN  False    True          True
# 19   8.73   6.54   ...        0.0    NaN    NaN  False    True          True
#
#     Crs_Bear  Bear5  Bearish  Signal
# 0        NaN    NaN      NaN     NaN
# 1        NaN    NaN      NaN     NaN
# 2        NaN    NaN      NaN     NaN
# 3        NaN    NaN      NaN     NaN
# 4        NaN    NaN      NaN     NaN
# 5        NaN    NaN      0.0     NaN
# 6        NaN    NaN      0.0     NaN
# 7        NaN    NaN      0.0     NaN
# 8        NaN    NaN      0.0     NaN
# 9        NaN    NaN      0.0     NaN
# 10       NaN    NaN      0.0     NaN
# 11       NaN    NaN      0.0     NaN
# 12       NaN    NaN      0.0     NaN
# 13       NaN    NaN      0.0     NaN
# 14       NaN    NaN      0.0     NaN
# 15       NaN    NaN      0.0     NaN
# 16 -7.454333    NaN      0.0     NaN
# 17 -7.323000  False      0.0     NaN
# 18 -7.323000  False      0.0     NaN
# 19 -7.323000  False      0.0     NaN
#
# [20 rows x 40 columns]

# %%
type(target_results["Bear3"][15])
# Out:
# bool
