# %% [markdown]
# # Sort Excel Files on Date Ascending

# %%
import pandas as pd
import csv
import os
from os import listdir
from os.path import isfile, join

import settings

only_files = [f for f in listdir(settings.data_file_path) if isfile(join(settings.data_file_path, f))]
only_files.pop(0)
print(only_files)
# Out:
# ['0x.csv', '1337.csv', '1credit.csv', '23-skidoo.csv', '2give.csv', '300-token.csv', '42-coin.csv', '808coin.csv', '8bit.csv', '9coin.csv', 'abncoin.csv', 'aces.csv', 'Achain.csv', 'acoin.csv', 'adcoin.csv', 'adelphoi.csv', 'adshares.csv', 'adtoken.csv', 'advanced-internet-blocks.csv', 'adx-net.csv', 'adzcoin.csv', 'aeon.csv', 'aeternity.csv', 'agoras-tokens.csv', 'agrolifecoin.csv', 'aidos-kuneen.csv', 'alexium.csv', 'allion.csv', 'allsafe.csv', 'alpacoin.csv', 'alphabitcoinfund.csv', 'altcoin-alt.csv', 'ambercoin.csv', 'amis.csv', 'ammo-rewards.csv', 'amsterdamcoin.csv', 'anarchistsprime.csv', 'animecoin.csv', 'anoncoin.csv', 'antibitcoin.csv', 'antilitecoin.csv', 'antimatter.csv', 'applebyte.csv', 'applecoin-apw.csv', 'apx.csv', 'aquariuscoin.csv', 'aragon.csv', 'arbit.csv', 'arcade-token.csv', 'arcticcoin.csv', 'ardor.csv', 'argentum.csv', 'argus.csv', 'aricoin.csv', 'ark.csv', 'artex-coin.csv', 'asch.csv', 'aseancoin.csv', 'asiacoin.csv', 'asiadigicoin.csv', 'asiccoin.csv', 'asset-backed-coin.csv', 'atc-coin.csv', 'atmcoin.csv', 'atmos.csv', 'atomic-coin.csv', 'audiocoin.csv', 'augur.csv', 'auroracoin.csv', 'aurumcoin.csv', 'avatarcoin.csv', 'avoncoin.csv', 'axfunds.csv', 'axiom.csv', 'b3coin.csv', 'bagcoin.csv', 'bancor.csv', 'bankcoin.csv', 'basic-attention-token.csv', 'bata.csv', 'batcoin.csv', 'bbqcoin.csv', 'bcap.csv', 'beatcoin.csv', 'beavercoin.csv', 'belacoin.csv', 'benjirolls.csv', 'berncash.csv', 'bestchain.csv', 'betacoin.csv', 'BiblePay.csv', 'bigup.csv', 'billarycoin.csv', 'binance-coin.csv', 'biobar.csv', 'bios-crypto.csv', 'bipcoin.csv', 'birds.csv', 'bit20.csv', 'bitalphacoin.csv', 'bitasean.csv', 'bitbar.csv', 'bitbay.csv', 'bitbean.csv', 'bitbtc.csv', 'bitcedi.csv', 'bitcentavo.csv', 'bitcloud.csv', 'bitcny.csv', 'bitcoal.csv', 'bitcoin copy.csv', 'bitcoin-21.csv', 'bitcoin-cash.csv', 'bitcoin-planet.csv', 'bitcoin-plus.csv', 'bitcoin-scrypt.csv', 'bitcoin-unlimited.csv', 'bitcoin.csv', 'bitcoindark.csv', 'bitcoinfast.csv', 'bitcointx.csv', 'bitconnect.csv', 'bitcore.csv', 'bitcrystals.csv', 'bitcurrency.csv', 'bitdeal.csv', 'biteur.csv', 'bitgem.csv', 'bitgold.csv', 'bitland.csv', 'bitmark.csv', 'bitok.csv', 'bitpark-coin.csv', 'bitquark.csv', 'bitquence.csv', 'bitradio.csv', 'bitsend.csv', 'bitshares-music.csv', 'bitshares.csv', 'bitsilver.csv', 'bitstar.csv', 'bitswift.csv', 'bittokens.csv', 'bitusd.csv', 'bitvolt.csv', 'bitz.csv', 'bitzeny.csv', 'blackcoin.csv', 'blackstar.csv', 'blakecoin.csv', 'blakestar.csv', 'blazecoin.csv', 'blazercoin.csv', 'blitzcash.csv', 'blockcat.csv', 'blocknet.csv', 'blockpay.csv', 'blocktix.csv', 'bluecoin.csv', 'bnrtxcoin.csv', 'bolenum.csv', 'bolivarcoin.csv', 'bongger.csv', 'boolberry.csv', 'boostcoin.csv', 'bottlecaps.csv', 'bowscoin.csv', 'braincoin.csv', 'breakout-stake.csv', 'breakout.csv', 'briacoin.csv', 'britcoin.csv', 'btcdragon.csv', 'btcgold.csv', 'btctalkcoin.csv', 'btsr.csv', 'bumbacoin.csv', 'bunnycoin.csv', 'burst.csv', 'burstocean.csv', 'byteball.csv', 'bytecent.csv', 'bytecoin-bcn.csv', 'bytom.csv', 'c-bit.csv', 'cabbage.csv', 'cachecoin.csv', 'cagecoin.csv', 'californium.csv', 'caliphcoin.csv', 'campuscoin.csv', 'canada-ecoin.csv', 'cannabiscoin.csv', 'cannacoin.csv', 'cannation.csv', 'capricoin.csv', 'carboncoin.csv', 'cashcoin.csv', 'cashme.csv', 'casino.csv', 'casinocoin.csv', 'catcoin.csv', 'cbd-crystals.csv', 'ccminer.csv', 'centra.csv', 'centurion.csv', 'chaincoin.csv', 'chancoin.csv', 'cheapcoin.csv', 'chesscoin.csv', 'chncoin.csv', 'chronobank.csv', 'chronos.csv', 'circuits-of-value.csv', 'civic.csv', 'clams.csv', 'clinton.csv', 'cloakcoin.csv', 'clubcoin.csv', 'coeval.csv', 'coexistcoin.csv', 'cofound-it.csv', 'coimatic-2.csv', 'coin.csv', 'coin2-1.csv', 'coindash.csv', 'CoinMarketCapMarkets 2017-08-27.csv', 'CoinMarketCapMarkets.csv', 'coinonat.csv', 'coinonatx.csv', 'colossuscoin-v2.csv', 'comet.csv', 'compcoin.csv', 'compucoin.csv', 'concoin.csv', 'condensate.csv', 'corgicoin.csv', 'counterparty.csv', 'coupecoin.csv', 'crave.csv', 'cream.c ...

# %%
count = 1
for market in only_files:
    
    # read in the file
    file_path = os.path.join(settings.data_file_path,  market)
    print(str(count)+". "+market)
    fileDF = pd.read_csv(file_path,header=None )
    # print(fileDF)
    # convert date column to datetime type
    fileDF[0] =  pd.to_datetime(fileDF[0], format='%b %d %Y')

    # sort it
    sortedDF = fileDF.sort([0], ascending=True)
    #print(sorted)

    # convert date column to string
    #sortedDF[0] =  pd.to_datetime(sortedDF[0], format='%b %d %Y')
    sortedDF[0] =  sortedDF[0].dt.strftime('%Y-%m-%d')
    #sortedDF[0].apply(lambda x: x.strftime('%b %d %Y'))

    # save it
    sortedDF.to_csv(file_path, index=False, header=False)
    count+=1
# Out:
# 1. 0x.csv
# 2. 1337.csv
# 3. 1credit.csv
# 4. 23-skidoo.csv
# 5. 2give.csv
# 6. 300-token.csv
# 7. 42-coin.csv
# 8. 808coin.csv
# 9. 8bit.csv
# 10. 9coin.csv
# 11. abncoin.csv
# 12. aces.csv
# 13. Achain.csv
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ------------------------------------
# TypeErrorTraceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     408             try:
# --> 409                 values, tz = tslib.datetime_to_datetime64(arg)
#     410                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/tslib.pyx in pandas.tslib.datetime_to_datetime64 (pandas/tslib.c:29768)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueErrorTraceback (most recent call last)
# <ipython-input-49-a226ea451d52> in <module>()
#       9     # print(fileDF)
#      10     # convert date column to datetime type
# ---> 11     fileDF[0] =  pd.to_datetime(fileDF[0], format='%b %d %Y')
#      12
#      13     # sort it
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/util/decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/tseries/tools.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#     289                         yearfirst=yearfirst,
#     290                         utc=utc, box=box, format=format, exact=exact,
# --> 291                         unit=unit, infer_datetime_format=infer_datetime_format)
#     292
#     293
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/tseries/tools.py in _to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, freq, infer_datetime_format)
#     418     elif isinstance(arg, ABCSeries):
#     419         from pandas import Series
# --> 420         values = _convert_listlike(arg._values, False, format)
#     421         return Series(values, index=arg.index, name=arg.name)
#     422     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     410                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     411             except (ValueError, TypeError):
# --> 412                 raise e
#     413
#     414     if arg is None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     374                     try:
#     375                         result = tslib.array_strptime(
# --> 376                             arg, format, exact=exact, errors=errors)
#     377                     except tslib.OutOfBoundsDatetime:
#     378                         if errors == 'raise':
#
# pandas/tslib.pyx in pandas.tslib.array_strptime (pandas/tslib.c:57701)()
#
# ValueError: time data 'No data was found for the selected time period.' does not match format '%b %d %Y' (match)
