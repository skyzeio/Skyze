# %% [markdown]
# # Martin Flow Calculations

# %% [markdown]
# ## Parameters

# %%
volume = 400                    # litres
circulation = 100               # litres/minute
fibre_av_length_start = 10      # millimeters
fibre_av_length_finish = 0.1    # mm
cycles_to_process = 20          # Cycles to go from av start to end fibre length

time_one_cycle = volume / circulation                    # minutes ... circulate the entire volume
time_one_process = cycles_to_process * time_one_cycle    # minutes ... process to get target av fibre length

# Content flow
flow_in  = 2      # litres / minute
flow_out = 2      # litres / minute

# Stabilsation
stabilisation_factor = .001   # if the av length change between cycles is < .01% then stabilasation has occurred

print("One cycle takes:   "+str(time_one_cycle)+" minutes")
print("One process takes: "+str(time_one_process)+" minutes")

import numpy as np
# Out:
# One cycle takes:   4.0 minutes
# One process takes: 80.0 minutes

# %% [markdown]
# ## Change in Fibre Lengths
# ### Start with full volume no adding or removing of contents

# %%
# Assume average fibre length change per circulation is linear

delta_fibre_length_cycle  = 1 / cycles_to_process
delta_fibre_length_minute = 1 / time_one_process

print("delta_fibre_length_cycle:   "+str(delta_fibre_length_cycle)+" %")
print("delta_fibre_length_minute: "+str(delta_fibre_length_minute)+" %")
# Out:
# delta_fibre_length_cycle:   0.05 %
# delta_fibre_length_minute: 0.0125 %

# %%
import matplotlib.pyplot as plt

data = []
i = fibre_av_length_start
while i >= fibre_av_length_finish:
    data.append(i)
    i -= fibre_av_length_start*delta_fibre_length_cycle

plt.figure
plt.title('Change in Fibre Length (%) over time', size = 'large')
plt.xlabel("Cycles")
plt.ylabel("Av Fibre Length (mm)")
plt.plot(data)
plt.show()

print("\n\nData Points: " + str(data))
# Out:
# Data Points: [10, 9.5, 9.0, 8.5, 8.0, 7.5, 7.0, 6.5, 6.0, 5.5, 5.0, 4.5, 4.0, 3.5, 3.0, 2.5, 2.0, 1.5, 1.0, 0.5]

# %% [markdown]
# ##  Run for full processing cycle THEN start content flow
# Start with full volume for full processing cycle so that the target average length has been reached\n
# THEN start the content flow

# %%
start_volume = volume
start_av_length = fibre_av_length_finish #fibre_av_length_start
prev_av_length = start_av_length
print(start_av_length)
data = [start_av_length]
stabilisation_point = 0
for i in range(cycles_to_process*8):
    new_av_length = ( prev_av_length*(start_volume-flow_out)*(1-delta_fibre_length_cycle)
                      + flow_in*fibre_av_length_start) / volume
    # check if equilibrium has been reached
    if (prev_av_length-new_av_length)/prev_av_length < stabilisation_factor:
        stabilisation_point = i
       # break
    
    # remember length for next iteration
    prev_av_length = new_av_length
    # round it to 4 decimal places
    new_av_length = float("{0:.6f}".format(new_av_length))
    # add it to the list to graph
    data.append(new_av_length)
    
    
# Plot it
plt.figure
plt.title('Change in Average Fibre Length over time (cycles)', size = 'large')
plt.xlabel("Cycles")
plt.ylabel("Av Fibre Length (mm)")
plt.plot(data)
plt.show()

print("=== SUMMARY ================== ")
print("Length stabilisation occurs at cycle: "+str(stabilisation_point)+" ... after "+str(stabilisation_point*time_one_cycle)+" minutes.")
print("with averagle length of: "+str(float("{0:.4f}".format(prev_av_length))))
print("\n\nData Points: " + str(data))
# Out:
# 0.1
# === SUMMARY ==================
# Length stabilisation occurs at cycle: 159 ... after 636.0 minutes.
# with averagle length of: 0.9131
#
#
# Data Points: [0.1, 0.144525, 0.186612, 0.226395, 0.264, 0.299546, 0.333146, 0.364906, 0.394928, 0.423305, 0.450129, 0.475485, 0.499452, 0.522107, 0.543522, 0.563764, 0.582898, 0.600984, 0.61808, 0.63424, 0.649516, 0.663955, 0.677603, 0.690504, 0.702699, 0.714226, 0.725123, 0.735422, 0.745158, 0.75436, 0.763059, 0.771282, 0.779054, 0.786401, 0.793345, 0.79991, 0.806115, 0.81198, 0.817524, 0.822765, 0.827718, 0.832401, 0.836827, 0.84101, 0.844965, 0.848703, 0.852237, 0.855577, 0.858734, 0.861718, 0.864539, 0.867206, 0.869726, 0.872109, 0.874361, 0.876489, 0.878502, 0.880404, 0.882202, 0.883901, 0.885507, 0.887026, 0.888461, 0.889818, 0.8911, 0.892313, 0.893459, 0.894542, 0.895566, 0.896533, 0.897448, 0.898313, 0.89913, 0.899903, 0.900633, 0.901324, 0.901976, 0.902593, 0.903176, 0.903727, 0.904248, 0.90474, 0.905206, 0.905646, 0.906062, 0.906455, 0.906826, 0.907178, 0.90751, 0.907824, 0.90812, 0.908401, 0.908666, 0.908916, 0.909153, 0.909377, 0.909589, 0.909789, 0.909978, 0.910156, 0.910325, 0.910485, 0.910636, 0.910779, 0.910914, 0.911041, 0.911162, 0.911275, 0.911383, 0.911485, 0.911581, 0.911672, 0.911758, 0.911839, 0.911916, 0.911989, 0.912057, 0.912122, 0.912183, 0.912241, 0.912296, 0.912348, 0.912397, 0.912443, 0.912487, 0.912528, 0.912567, 0.912604, 0.912639, 0.912672, 0.912703, 0.912733, 0.912761, 0.912787, 0.912812, 0.912836, 0.912858, 0.912879, 0.912899, 0.912918, 0.912935, 0.912952, 0.912968, 0.912983, 0.912997, 0.913011, 0.913023, 0.913035, 0.913047, 0.913057, 0.913067, 0.913077, 0.913086, 0.913094, 0.913103, 0.91311, 0.913117, 0.913124, 0.913131, 0.913137, 0.913143]

# %% [markdown]
# ##  Run with content flow
# Start with full volume with the content flow started from the beginning

# %%
import numpy as np

volume = 400                    # litres
circulation = 100               # litres/minute
fibre_av_length_start = 10      # millimeters
fibre_av_length_finish = 0.1    # mm
cycles_to_process = 20          # Cycles to go from av start to end fibre length

time_one_cycle = volume / circulation                    # minutes ... circulate the entire volume
time_one_process = cycles_to_process * time_one_cycle    # minutes ... process to get target av fibre length

# Content flow
flow_in  = 2      # litres / minute
flow_out = 2      # litres / minute
flow_in = flow_out = 0.1652

# Stabilsation
stabilisation_factor = .001   # if the av length change between cycles is < .01% then stabilasation has occurred
max_cycles = 200

print("One cycle takes:   "+str(time_one_cycle)+" minutes")
print("One process takes: "+str(time_one_process)+" minutes")
print()
print("Starting Av Fibre Length: "+str(fibre_av_length_start)+"mm")
print("Target Av Fibre Length: "+str(fibre_av_length_finish)+"mm")
print()
print("Flow in: "+str(flow_in)+" litres")
print("Flow out: "+str(flow_out)+" litres")
print()
print("Stabalisation factor: "+str(stabilisation_factor)+"mm")
print("Maximum cycles: "+str(max_cycles))

# Run the cycles
start_volume = volume
prev_av_length = start_av_length
data = [start_av_length]
continue_processing = True
process_count = 1
while prev_av_length > fibre_av_length_finish and continue_processing:
    new_av_length = ( prev_av_length*(start_volume-flow_out)*(1-delta_fibre_length_cycle)
                      + flow_in*fibre_av_length_start) / volume
    # Change of length
    delta_av_length = prev_av_length - new_av_length
    # remember length for next iteration
    prev_av_length = new_av_length
    # round it to 4 decimal places
    new_av_length = float("{0:.6f}".format(new_av_length))
    # add it to the list to graph
    data.append(new_av_length)
    # see if we have finished
    process_count += 1
    continue_processing = delta_av_length > stabilisation_factor and process_count <= max_cycles
    
    
    
# Plot it
plt.figure
plt.title('Change in Average Fibre Length over time (cycles)', size = 'large')
plt.xlabel("Cycles")
plt.ylabel("Av Fibre Length (mm)")
#plt.semilogy(np.exp(data))
log_data = np.log(data)
#plt.plot(log_data)
plt.plot(data)
plt.show()


# Cycles to stabalise
stabilisation_point = len(data)

print("=== SUMMARY ================== ")
print("Length stabilisation occurs at cycle: "+str(stabilisation_point)+" ... after "+str(stabilisation_point*time_one_cycle)+" minutes.")
print("with averagle length of: "+str(float("{0:.4f}".format(prev_av_length))))
print("Stabilisation is when change between cycles < "+str(stabilisation_factor))
print("\n\nData Points: " + str(data))
# Out:
# One cycle takes:   4.0 minutes
# One process takes: 80.0 minutes
#
# Starting Av Fibre Length: 10mm
# Target Av Fibre Length: 0.1mm
#
# Flow in: 0.1652 litres
# Flow out: 0.1652 litres
#
# Stabalisation factor: 0.001mm
# Maximum cycles: 200
# === SUMMARY ==================
# Length stabilisation occurs at cycle: 123 ... after 492.0 minutes.
# with averagle length of: 0.1
# Stabilisation is when change between cycles < 0.001
#
#
# Data Points: [10, 9.500206, 9.025599, 8.574908, 8.146928, 7.740515, 7.354582, 6.988098, 6.640081, 6.309602, 5.995776, 5.697765, 5.414771, 5.146038, 4.890847, 4.648516, 4.418396, 4.199873, 3.992361, 3.795307, 3.608182, 3.430488, 3.261747, 3.10151, 2.949348, 2.804853, 2.66764, 2.537341, 2.413609, 2.296111, 2.184535, 2.078581, 1.977967, 1.882422, 1.791692, 1.705535, 1.623719, 1.546026, 1.472248, 1.402188, 1.335658, 1.272482, 1.212488, 1.155518, 1.101419, 1.050046, 1.001261, 0.954936, 0.910944, 0.869169, 0.8295, 0.79183, 0.756057, 0.722088, 0.68983, 0.659198, 0.630109, 0.602487, 0.576256, 0.551347, 0.527693, 0.505232, 0.483902, 0.463647, 0.444413, 0.426148, 0.408803, 0.392333, 0.376692, 0.36184, 0.347736, 0.334342, 0.321624, 0.309547, 0.298078, 0.287187, 0.276845, 0.267024, 0.257698, 0.248842, 0.240432, 0.232447, 0.224863, 0.217662, 0.210823, 0.204329, 0.198163, 0.192307, 0.186746, 0.181465, 0.176451, 0.171689, 0.167167, 0.162873, 0.158796, 0.154924, 0.151247, 0.147755, 0.144439, 0.141291, 0.138301, 0.135461, 0.132765, 0.130205, 0.127774, 0.125465, 0.123272, 0.12119, 0.119213, 0.117336, 0.115553, 0.11386, 0.112252, 0.110726, 0.109276, 0.107899, 0.106592, 0.105351, 0.104172, 0.103052, 0.101989, 0.10098, 0.100021]
